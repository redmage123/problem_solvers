# %% [markdown]
# # Modern problem solvers
#
# In this lecture, we are going to look at the concept of a generic problem solver.
#
# We'll apply this concept to a variety of problems, such as
# - Breadth and Depth First Search.
# - SAT Solvers.
# - Reinforcement Learning.
# - Temporal Logic with TLA and Z3.
# - Generic Monte Carlo Tree Searches with Convolutional Neural Networks and Machine Learning.

# %% [markdown]
# ## What to keep in mind.
# - How little code is needed to express these ideas.
# - How the tooling is generic and pluggable so it can be applied to a broad class of problems.
# - While the examples are applied to trivial or toy problems, they can be scaled up to problems that involve many different variables.

# %% [markdown]
# ## Breadth first and Depth first searches.
#
# The first class of problems that we will apply to are the tree searches.  Generally there are two methods for searching a tree, breadth first or depth first.

# %% [markdown]
# <img src='graphics/tree.png'/>

# %% [markdown]
# Often times, finding the shortest path to a node in a tree uses breadth first search. However, Monte Carlo tree searches, such as those used by the AlphaGo program, use depth-first searches.

# %% [markdown]
# # A small digression
# Here we will digress to discuss in general the details of Monte Carlo simlations and the Monte Carlo Tree Search.

# %% [markdown]
# ### What is a Monte Carlo simulation?
#
# How do casinos earn money? The trick is simple, the longer you play, the more likely it is that you will lose money to the casino.  Let us take a look at how this works with a simple Monte Carlo simulation.

# %% [markdown]
# Consider an imaginary game in which our player ‘Jack’, rolls an imaginary dice to get an outcome of 1 to 100. If Jack rolls anything from 1–51, the house wins, but if the number rolled is from 52–100, Jack wins. Simple enough?

# %% [markdown]
# Before simulating the outcomes, let’s calculate the house edge. The house edge displays the advantage the casino has in winning the bet. It’s the casino’s average profit from a player’s bet.

# %% [markdown]
# Let’s suppose Jack bets $1 on this game.<br>
# Probability of Jack winning = 49/100<br>
# Probability of the casino winning = 51/100<br>
# Expected profit for the player= 1*(49/100) - 1*(51/100) = -0.02 = -2%<br>

# %% [markdown]
# Therefore, the house edge in our imaginary game is 2%. For comparison, the lowest house edge in European Roulette is 2.7%. In short, we have a better chance of winning in our imaginary game than in Roulette.

# %% [markdown]
# Now, let’s simulate different scenarios in Python to visualize the different outcomes if the player kept betting continuously.

# %%
# Import our required libraries. 
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
''' We need a dice simulator which throws a value 
    from 1–100 with uniform probability distribution.
    Let’s create a function in Python which returns
    "True" if the player wins and "False" 
    if the Casino wins.
''' 
 
def rolldice():
    
    dice = random.randint(1,100)
    if dice <=51:
        return False
    elif dice >51 & dice <=100:
        return True

# %%
''' Create a function that simulates the bets. 
    We need to provide three arguments for the  
    function :
    1. Total funds : The money the player is
       starting with ($10,000)
    2. Wager Amount : The amount the player bets
       in each game ($100)
    3. Total plays : The number of times the
       player plays the game
       (This value is changed for creating 
        different scenarios)
'''

def play(total_funds, wager_amount, total_plays):
    
    #Create empty lists for :
    # 1.Play_number and 
    # 2.Funds available
    # 3.Final Fund
    Play_num = []
    Funds = []
    
# Start with play number 1
    play = 1
    
# If number of plays is less than the max number of plays
# we have set
    while play < total_plays:
        #If we win
        if rolldice():
            #Add the money to our funds
            total_funds = total_funds + wager_amount
            #Append the play number
            Play_num.append(play)
            #Append the new fund amount
            Funds.append(total_funds)
            
         #If the house wins
        else:
            #subtract the wager from our funds
            total_funds = total_funds - wager_amount 
            #Append the play number
            Play_num.append(play)
            #Append the new fund amount
            Funds.append(total_funds)
            
                
        #Increase the play number by 1
        play += 1
        
        #Line plot of funds over time
    plt.plot(Play_num,Funds)
    Final_funds.append(Funds[-1])
    return(Final_funds)

# %%
#Call the function to simulate the plays and calculate the remaining #funds of the player after all the bets
#Intialize the scenario number to 1
x=1
#Create a list for calculating final funds
Final_funds= []
while x<=100:
    ending_fund = play(10000,100,5)
    x+=1
    
    #Plot the line plot of "Account Value" vs "The number of plays"
plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

#Print the money the player ends with
print("The player starts the game with $10,000 and ends with $" + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9942.0

# %% [markdown]
# In the previous code, we set the total number of simulations (plays) to 5.  Let's see what happens when we increase this to 10.

# %%
#Call the function to simulate the plays and calculate the remaining #funds of the player after all the bets
#Intialize the scenario number to 1
x=1
#Create a list for calculating final funds
Final_funds= []
while x<=100:
    ending_fund = play(10000,100,10)
    x+=1
    
    #Plot the line plot of "Account Value" vs "The number of plays"
plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

#Print the money the player ends with
print("The player starts the game with $10,000 and ends with $" + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9994.0

# %% [markdown]
# Now let's do 50 simulations.

# %%
#Call the function to simulate the plays and calculate the remaining #funds of the player after all the bets
#Intialize the scenario number to 1
x=1
#Create a list for calculating final funds
Final_funds= []
while x<=100:
    ending_fund = play(10000,100,50)
    x+=1
    
    #Plot the line plot of "Account Value" vs "The number of plays"
plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

#Print the money the player ends with
print("The player starts the game with $10,000 and ends with $" + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9924.0

# %% [markdown]
# Let's run it again with 100 simulations.

# %%
#Call the function to simulate the plays and calculate the remaining #funds of the player after all the bets
#Intialize the scenario number to 1
x=1
#Create a list for calculating final funds
Final_funds= []
while x<=100:
    ending_fund = play(10000,100,100)
    x+=1
    
    #Plot the line plot of "Account Value" vs "The number of plays"
plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

#Print the money the player ends with
print("The player starts the game with $10,000 and ends with $" + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $9816.0

# %% [markdown]
# 1000 Simulations.

# %%
#Call the function to simulate the plays and calculate the remaining #funds of the player after all the bets
#Intialize the scenario number to 1
x=1
#Create a list for calculating final funds
Final_funds= []
while x<=100:
    ending_fund = play(10000,100,1000)
    x+=1
    
    #Plot the line plot of "Account Value" vs "The number of plays"
plt.ylabel('Player Money in $')
plt.xlabel('Number of bets')
plt.show()

#Print the money the player ends with
print("The player starts the game with $10,000 and ends with $" + str(sum(ending_fund)/len(ending_fund)))
# Out:
# The player starts the game with $10,000 and ends with $7900.0

# %% [markdown]
# We can definitely see that the trend is downward.
# If we play long enough, we'll lose all of our money.

# %% [markdown]
# ## Another example of a Monte Carlo simulation.
#
# Let's see how we can use the Monte Carlo simulation to model the movement of an equity and predict the price going forward.

# %% [markdown]
# If we want to buy a particular stock, for example, we may like to try to look into the future and attempt to predict what kind of returns we can expect with what kind of probability, or we may be interested in investigating what potential extreme outcomes we may experience and how exposed we are to the risk of ruin or, on the flip side, superior returns.

# %% [markdown]
# To set up our simulation, we need to estimate the expected level of return mu($\mu$) and volatility (vol) of the stock in question. This data can be estimated from historic prices, with the simplest methods just assuming past mean return and volatility levels will continue into the future. One could also adjust historic data to account for investor views or market regime changes etc, however to keep things simple and concentrate on the code we will just set simple return and volatility levels based on past price data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quandl
from math import sqrt
quandl.ApiConfig.api_key = 'Uvc7KJzykfvBLjVkNDy2'
selected = ['AAPL']
data = quandl.get_table('WIKI/PRICES', ticker = selected,
                        qopts = { 'columns': ['ticker','date', 'adj_close'] },
                        date = { 'gte': '2016-12-31', 'lte':'2017-12-31' }, paginate=True)

# %%
data
# Out:
#      ticker       date   adj_close
# None
# 0      AAPL 2017-12-29  169.230000
# 1      AAPL 2017-12-28  171.080000
# 2      AAPL 2017-12-27  170.600000
# 3      AAPL 2017-12-26  170.570000
# 4      AAPL 2017-12-22  175.010000
# ...     ...        ...         ...
# 244    AAPL 2017-01-09  117.520300
# 245    AAPL 2017-01-06  116.453639
# 246    AAPL 2017-01-05  115.169696
# 247    AAPL 2017-01-04  114.586983
# 248    AAPL 2017-01-03  114.715378
#
# [249 rows x 3 columns]

# %%
days = (data.index[-1] - data.index[0])

# %%
days
# Out:
# 248

# %% [markdown]
# Here we will calculate the Compound Annual Growth Rate.
#
# Compound annual growth rate (CAGR) is the rate of return that would be required for an investment to grow from its beginning balance to its ending balance, assuming the profits were reinvested at the end of each year of the investment’s lifespan.

# %%
cagr = ((((data['adj_close'].iloc[1]) / data['adj_close'].iloc[-1])) ** (365.0/days)) - 1

# %%
cagr
# Out:
# 0.800806439343348

# %%
print ('CAGR =',str(round(cagr,4)*100)+"%")
# Out:
# CAGR = 80.08%

# %%
mu = cagr

# %%
data['Returns'] = data['adj_close'].pct_change()

# %%
data
# Out:
#      ticker       date   adj_close   Returns
# None
# 0      AAPL 2017-12-29  169.230000       NaN
# 1      AAPL 2017-12-28  171.080000  0.010932
# 2      AAPL 2017-12-27  170.600000 -0.002806
# 3      AAPL 2017-12-26  170.570000 -0.000176
# 4      AAPL 2017-12-22  175.010000  0.026030
# ...     ...        ...         ...       ...
# 244    AAPL 2017-01-09  117.520300 -0.001007
# 245    AAPL 2017-01-06  116.453639 -0.009076
# 246    AAPL 2017-01-05  115.169696 -0.011025
# 247    AAPL 2017-01-04  114.586983 -0.005060
# 248    AAPL 2017-01-03  114.715378  0.001120
#
# [249 rows x 4 columns]

# %%
vol = data['Returns'].std()*sqrt(248)

# %%
vol
# Out:
# 0.17514921512148748

# %%
print ('mu =',str(round(cagr,4)*100)+"%")
print ("Annual Volatility =",str(round(vol,4)*100)+"%")
# Out:
# mu = 80.08%
# Annual Volatility = 17.51%

# %% [markdown]
# Now we know our mean return input (mu) is 80.08% and our volatility input (vol) is 17.51% – the code to actually run the Monte Carlo simulation is as follows:

# %%
#Define Variables
S = data['adj_close'][1] #starting stock price (i.e. last available real stock price)
T = 248 #Number of trading days
mu = 0.8008 #Return
vol = 0.1766 #Volatility
#create list of daily returns using random normal distribution
daily_returns=np.random.normal((mu/T),vol/sqrt(T),T)+1
#set starting price and create price series generated by above random daily returns
price_list = [S]
for x in daily_returns:
    price_list.append(price_list[-1]*x)
#Generate Plots - price series and histogram of daily returns
plt.plot(price_list)
plt.show()
plt.hist(daily_returns-1, 100) #Note that we run the line plot and histogram separately, not simultaneously.
plt.show()

# %% [markdown]
# The above code basically ran a single simulation of potential price series evolution over a trading year (248 days), based upon a draw of random daily returns that follow a normal distribution. This is represented by the single line series shown in the first chart. The second chart plots a histogram of those random daily returns over the year period.

# %% [markdown]
# We have managed to successfully simulate a year’s worth of future daily price data, however this really doesn’t afford us much insight into risk and return characteristics of the stock as we only have one randomly generated path. The likelihood of the actual price evolving exactly as described in the above charts is nearly zero.

# %% [markdown]
# The real insight of a Monte Carlo simulation is gained from running thousands, tens of thousands or even hundreds of thousands of simulations, with each run producing a different series of potential price evolution based upon the same stock characteristics (mu and vol).

# %%
#Define Variables
S = data['adj_close'][1] #starting stock price (i.e. last available real stock price)
T = 248 #Number of trading days
mu = 0.8008 #Return
vol = 0.1766 #Volatility
#choose number of runs to simulate - I have chosen 1000
for i in range(1000):
#create list of daily returns using random normal distribution
    daily_returns=np.random.normal((mu/T),vol/sqrt(T),T)+1
#set starting price and create price series generated by above random daily returns
    price_list = [S]
    for x in daily_returns:
        price_list.append(price_list[-1]*x)
#Generate Plots - price series and histogram of daily returns
    plt.plot(price_list)
plt.show()
#plt.hist(daily_returns-1, 100) #Note that we run the line plot and histogram separately, not simultaneously.
#plt.show()

# %% [markdown]
# This give us the following plot of the 1000 different simulated price series

# %% [markdown]
# Now we can see the potential outcomes generated from 1000 different simulations, all based on the same basic inputs, allowing for the randomness of the daily return series.
#
# Note that the spread of final prices is quite large, ranging from around \\$45 to $500 USD.

# %% [markdown]
# The graph is quite cluttered, which limits the amount of usable information gleaned.  So, let's add back in the histogram of the distribution of end stock prices.

# %%
#Define Variables
S = data['adj_close'][1] #starting stock price (i.e. last available real stock price)
T = 248 #Number of trading days
mu = 0.8008 #Return
vol = 0.1766 #Volatility
result = []
#choose number of runs to simulate - I have chosen 1000
for i in range(1000):
#create list of daily returns using random normal distribution
    daily_returns=np.random.normal((mu/T),vol/sqrt(T),T)+1
#set starting price and create price series generated by above random daily returns
    price_list = [S]
    for x in daily_returns:
        price_list.append(price_list[-1]*x)
#Generate Plots - price series and histogram of daily returns
    plt.plot(price_list)
    result.append(price_list[-1])
plt.show()
#plt.hist(daily_returns-1, 100) #Note that we run the line plot and histogram separately, not simultaneously.
#plt.show()

# %%
plt.hist(result,bins=50)
plt.show()

# %%
print (round(np.mean(result),2))
# Out:
# 382.13

# %% [markdown]
# We see that the median ending price of AAPL stock of all the sample runs is \\$385.05 USD.
#
# Note that as we run this again, these values will vary depending on the values of the daily ending price that we use in our Monte Carlo simulation.

# %% [markdown]
# Let's calculate the 5 percent quartile and the 95 percent quartile.

# %%
print ('5 % quartile = ', round(np.percentile(result,5),2))
print ('95 % quartile = ', round(np.percentile(result,95),2))
# Out:
# 5 % quartile =  279.01
# 95 % quartile =  505.88

# %% [markdown]
# So we now know that there is a 5% chance that our stock price will end up below around \\$287.53 and a 5% chance it will finish above \\$499.25.

# %% [markdown]
# So now we can begin to ask ourselves questions along the lines of “am I willing to risk a 5% chance of ending up with a stock worth less than \\$287.53, in order to chase an expected return of around 80%, giving us an expected stock price of around \\$385.05?”

# %% [markdown]
# ## Monte Carlo Tree Search

# %% [markdown]
# Games like Tic-Tac-Toe, Rubik’s Cube,
# Sudoku, Chess, Go and many others have a common property that lead to exponential increase in the number of possible actions that can be played.
#
# These possible steps increase exponentially as the game goes forward. Ideally if you can predict every possible move and its result, you can increase your chance of winning.
#
# But since the moves increase exponentially — the computation power that is required to calculate the moves also goes through the roof.

# %% [markdown]
# <img src = 'graphics/tictactoe.jpeg'/>

# %% [markdown]
# In the above graphic, the final winning move could be any one of the three cases shown.

# %% [markdown]
# Before we discover the right path(moves) that will lead us for the win. We first need to arrange the moves of the present state of the game. These moves connected together will look like a tree. Hence the name Tree Search.
#
# However, even a simple game like tic tac toe can generate a very large number of possible moves.  Games like Chess and Go are far more complex and have significantly more possible moves.  With Go, the number of possible moves exceeds the number of atoms in the known universe, which makes it computationally impossibe to search every move to find the optimum choice.
#
# See the diagram below to understand the sudden exponential increase in moves for Tic Tac Toe.

# %% [markdown]
# <img src = graphics/ttt_states.jpeg/>

# %% [markdown]
# A faster tree search can be achieved by giving more importance to some nodes from others and allowing their children nodes to be searched first to reach the correct solution.
#
# But how do we know which branch of the tree is the most favorable one to search?

# %% [markdown]
# To discover this we're going to use a tree search algorithm called the Monte Carlo Tree Search.  This algorithm is a Monte Carlo simulation that is optimized for tree searches.

# %% [markdown]
# MCTS is an algorithm that figures out the best move out of a set of moves by Selecting → Expanding → Simulating → Updating the nodes in tree to find the final solution. This method is repeated until it reaches the solution and learns the policy of the game.

# %% [markdown]
# Let's look in some detail as to how this works.

# %% [markdown]
# <img src='graphics/Flowchart.png'/>

# %% [markdown]
# Programmatically the algorithm looks like this:
#
# Rollout (S$_i$):<br>
# * loop forever<br>
#  +       if S$_i$ is a terminal state:<br>
#  + +         return value S$_i$<br>
# * A$_i$ = random (available actions (S$_i$))
# * S$_i$ = simulate(A$_i$,S$_i$)

# %% [markdown]
# The formula for calculating the value of any state is:
#
# $$ UCB1 (S_i) = \overline(V) + 2 \sqrt(\frac{ln N}  {n_i}) $$
#
# where $V$ is the current average value of the state. <br>
# $N$ is the number of parent visits<br>
# $n_i$ is the number of visits of this node.

# %% [markdown]
# Let's see what the initial state of our tree looks like:

# %% [markdown]
# <img src = 'graphics/Initial_State.png' />

# %% [markdown]
# We start with the first node, and we then have to choosed which node to traverse to.  To do this, we calculate the $max(ucb1)$ value. <br>
# However, in the first state, the maximum value is effectively infinite since we haven't visited any of the children nodes, so we simply visit each child in order from left to right. <br>
# The algorithm says that if we have a leaf node, and the number of visits is zero, then we do a rollout, which means to do a number of actions a random time recusively until we reach a terminal node. Note that the rollout is performed either via a set number of iterations or a set amount of time.   (In the example of tic tac toe, a terminal node is when three of the same symbol are in a row or when all squares are filled with no winner).

# %% [markdown]
# <img src='graphics/first_rollout.png'>

# %% [markdown]
# In the above diagram, we choose the left most leaf node and then play tic tac toe until we get to a terminal node (ex. player 'x' wins the game).
# When this happens, we assign some value to that terminal outcome.  For example '10' might be the value for a win and '5' for a draw.
#
# We then assign the value (v) to the first leaf node and increment the number of visits to that node by one.   We do the same thing with the root node.
#
# Finally we erase the intermediate rollout step.
